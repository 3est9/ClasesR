# %%
'Un {} vale {} {}'.format('€', 1.12, '$')
# Out:
# 'Un € vale 1.12 $'

# %%
'Un {2} vale {1}{0}'.format('€', 1.12, '$')
# Out:
# 'Un $ vale 1.12€'

# %%
#int() convierte a entero

# %%
int('12')

# %%
int(True)
# Out:
# 1

# %%
int('c')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 int('c')
#
# ValueError: invalid literal for int() with base 10: 'c'

# %%
#float() convierte a real

# %%
float('3.14')
# Out:
# 3.14

# %%
float(True)
# Out:
# 1.0

# %%
float('III')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 float('III')
#
# ValueError: could not convert string to float: 'III'

# %%
#str() convierte a cadena

# %%
str(3.14)
# Out:
# '3.14'

# %%
#bool() conviere a lógico

# %%
bool('0')
# Out:
# True

# %%
bool('3.14')
# Out:
# True

# %%
x = 3.14
y = 3 + 2

# %%
#Asignación múltiple de variables

# %%
a1, a2 = 1, 2

# %%
language = input('¿Cuál es tu lenguaje favorito? ')
# Out:
# ¿Cuál es tu lenguaje favorito?  Python

# %%
language
# Out:
# 'Python'

# %%
age = input('¿Cuál es tu edad? ')
# Out:
# ¿Cuál es tu edad?  21

# %%
age
# Out:
# '21'

# %%
si = input('Dame un número primo')
# Out:
# Dame un número primo 1

# %%
age + si
# Out:
# '211'

# %%
int(age) + int(si)
# Out:
# 22

# %%
age + si
# Out:
# '211'

# %%
print('Hola')
name = 'PEPE'
print('Hola', name)
print('El valor de pi es', 3.1415)
print('Hola', name, sep='')
print('Hola', name, end='!\n')
# Out:
# Hola
# Hola PEPE
# El valor de pi es 3.1415
# HolaPEPE
# Hola PEPE!

# %%
edad = 14
if edad <= 18:
    print('Menor')
elif edad>65:
    print('Jubilado')
else:
    print('Activo')
# Out:
# Menor

# %%
edad = 20
if edad <= 18:
    print('Menor')
elif edad>65:
    print('Jubilado')
else:
    print('Activo')
# Out:
# Activo

# %%
edad = 70
if (edad < 18):
    print('es menor gonzalo')
elif (edad>65):
    print('Jubilado')
    if (edad <=70):
        print('Lleva 5 años jubilado')
    else:
        print('Lleva más de 5 años jubilado')
else:
    print('está currando')
# Out:
# Jubilado
# Lleva 5 años jubilado

# %%
num = None
while num != 0:
    num = int(input('Introduce un número: '))
# Out:
# Introduce un número:  10
# Introduce un número:  4
# Introduce un número:  39
# Introduce un número:  76
# Introduce un número:  0

# %%
while True:
    num = int(input('Introduce un número: '))
    if num == 0:
        break
# Out:
# Introduce un número:  10
# Introduce un número:  5
# Introduce un número:  44
# Introduce un número:  0

# %%
i = 0
while (i <10):
    print(i)
    i+=1
    if (i==5):
        break
# Out:
# 0
# 1
# 2
# 3
# 4
